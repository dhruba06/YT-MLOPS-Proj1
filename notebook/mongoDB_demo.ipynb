# %%
import pandas as pd
import pymongo

df = pd.read_csv('data.csv')
df.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
# df should be converted into dict before we push it to mongodb

data = df.to_dict(orient='records')
# data

# %%
DB_NAME = "Proj1"
COLLECTION_NAME = "Proj1-Data"
CONNECTION_URL = "mongodb+srv://dhruvsardar90:0wgb46DK0n0SMlz7@cluster0.uearljb.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

# above, either remove your credentials or delete the mongoDB resource bofore pushing it to github.

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2730, in _ClientConnectionRetryable.run(self)
#    2729 try:
# -> 2730     return self._read() if self._is_read else self._write()
#    2731 except ServerSelectionTimeoutError:
#    2732     # The application may think the write was never attempted
#    2733     # if we raise ServerSelectionTimeoutError on the retry
#    2734     # attempt. Raise the original exception instead.
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2840, in _ClientConnectionRetryable._write(self)
#    2839 is_mongos = False
# -> 2840 self._server = self._get_server()
#    2841 with self._client._checkout(self._server, self._session) as conn:
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2823, in _ClientConnectionRetryable._get_server(self)
#    2819 """Retrieves a server object based on provided object context
#    2820
#    2821 :return: Abstraction to connect to server
#    2822 """
# -> 2823 return self._client._select_server(
#    2824     self._server_selector,
#    2825     self._session,
#    2826     self._operation,
#    2827     address=self._address,
#    2828     deprioritized_servers=self._deprioritized_servers,
#    2829     operation_id=self._operation_id,
#    2830 )
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1812, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1811 else:
# -> 1812     server = topology.select_server(
#    1813         server_selector,
#    1814         operation,
#    1815         deprioritized_servers=deprioritized_servers,
#    1816         operation_id=operation_id,
#    1817     )
#    1818 return server
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\topology.py:409, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     408 """Like select_servers, but choose a random server if several match."""
# --> 409 server = self._select_server(
#     410     selector,
#     411     operation,
#     412     server_selection_timeout,
#     413     address,
#     414     deprioritized_servers,
#     415     operation_id=operation_id,
#     416 )
#     417 if _csot.get_timeout():
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\topology.py:387, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     378 def _select_server(
#     379     self,
#     380     selector: Callable[[Selection], Selection],
#    (...)
#     385     operation_id: Optional[int] = None,
#     386 ) -> Server:
# --> 387     servers = self.select_servers(
#     388         selector, operation, server_selection_timeout, address, operation_id
#     389     )
#     390     servers = _filter_servers(servers, deprioritized_servers)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\topology.py:294, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     293 with self._lock:
# --> 294     server_descriptions = self._select_servers_loop(
#     295         selector, server_timeout, operation, operation_id, address
#     296     )
#     298     return [
#     299         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     300     ]
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\topology.py:344, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     334         _debug_log(
#     335             _SERVER_SELECTION_LOGGER,
#     336             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     342             failure=self._error_message(selector),
#     343         )
# --> 344     raise ServerSelectionTimeoutError(
#     345         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     346     )
#     348 if not logged_waiting:
#
# ServerSelectionTimeoutError: ac-swi5f6d-shard-00-02.uearljb.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-swi5f6d-shard-00-01.uearljb.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms),ac-swi5f6d-shard-00-00.uearljb.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 687600c380dcf48380e9137c, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('ac-swi5f6d-shard-00-00.uearljb.mongodb.net', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('ac-swi5f6d-shard-00-00.uearljb.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-swi5f6d-shard-00-01.uearljb.mongodb.net', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('ac-swi5f6d-shard-00-01.uearljb.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>, <ServerDescription ('ac-swi5f6d-shard-00-02.uearljb.mongodb.net', 27017) server_type: Unknown, rtt: None, error=NetworkTimeout('ac-swi5f6d-shard-00-02.uearljb.mongodb.net:27017: timed out (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
#
# During handling of the above exception, another exception occurred:
#
# _OperationCancelled                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Uploading data to MongoDB
# ----> 2 rec = collection.insert_many(data)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\collection.py:975, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974 blk.ops = list(gen())
# --> 975 blk.execute(write_concern, session, _Op.INSERT)
#     976 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:751, in _Bulk.execute(self, write_concern, session, operation)
#     749         return None
#     750 else:
# --> 751     return self.execute_command(generator, write_concern, session, operation)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:604, in _Bulk.execute_command(self, generator, write_concern, session, operation)
#     593     self._execute_command(
#     594         generator,
#     595         write_concern,
#    (...)
#     600         full_result,
#     601     )
#     603 client = self.collection.database.client
# --> 604 _ = client._retryable_write(
#     605     self.is_retryable,
#     606     retryable_bulk,
#     607     session,
#     608     operation,
#     609     bulk=self,  # type: ignore[arg-type]
#     610     operation_id=op_id,
#     611 )
#     613 if full_result["writeErrors"] or full_result["writeConcernErrors"]:
#     614     _raise_bulk_write_error(full_result)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2061, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2047 """Execute an operation with consecutive retries if possible
#    2048
#    2049 Returns func()'s return value on success. On error retries the same
#    (...)
#    2058 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2059 """
#    2060 with self._tmp_session(session) as s:
# -> 2061     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1947, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1942 # Ensure that the options supports retry_writes and there is a valid session not in
#    1943 # transaction, otherwise, we will not support retry behavior for this txn.
#    1944 retryable = bool(
#    1945     retryable and self.options.retry_writes and session and not session.in_transaction
#    1946 )
# -> 1947 return self._retry_internal(
#    1948     func=func,
#    1949     session=session,
#    1950     bulk=bulk,
#    1951     operation=operation,
#    1952     retryable=retryable,
#    1953     operation_id=operation_id,
#    1954 )
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:1993, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1956 @_csot.apply
#    1957 def _retry_internal(
#    1958     self,
#    (...)
#    1967     operation_id: Optional[int] = None,
#    1968 ) -> T:
#    1969     """Internal retryable helper for all client transactions.
#    1970
#    1971     :param func: Callback function we want to retry
#    (...)
#    1980     :return: Output of the calling func()
#    1981     """
#    1982     return _ClientConnectionRetryable(
#    1983         mongo_client=self,
#    1984         func=func,
#    1985         bulk=bulk,
#    1986         operation=operation,
#    1987         is_read=is_read,
#    1988         session=session,
#    1989         read_pref=read_pref,
#    1990         address=address,
#    1991         retryable=retryable,
#    1992         operation_id=operation_id,
# -> 1993     ).run()
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2735, in _ClientConnectionRetryable.run(self)
#    2730     return self._read() if self._is_read else self._write()
#    2731 except ServerSelectionTimeoutError:
#    2732     # The application may think the write was never attempted
#    2733     # if we raise ServerSelectionTimeoutError on the retry
#    2734     # attempt. Raise the original exception instead.
# -> 2735     self._check_last_error()
#    2736     # A ServerSelectionTimeoutError error indicates that there may
#    2737     # be a persistent outage. Attempting to retry in this case will
#    2738     # most likely be a waste of time.
#    2739     raise
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2816, in _ClientConnectionRetryable._check_last_error(self, check_csot)
#    2814 if not check_csot or (remaining is not None and remaining <= 0):
#    2815     assert self._last_error is not None
# -> 2816     raise self._last_error
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2730, in _ClientConnectionRetryable.run(self)
#    2728 self._check_last_error(check_csot=True)
#    2729 try:
# -> 2730     return self._read() if self._is_read else self._write()
#    2731 except ServerSelectionTimeoutError:
#    2732     # The application may think the write was never attempted
#    2733     # if we raise ServerSelectionTimeoutError on the retry
#    2734     # attempt. Raise the original exception instead.
#    2735     self._check_last_error()
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\mongo_client.py:2862, in _ClientConnectionRetryable._write(self)
#    2854         if self._retrying:
#    2855             _debug_log(
#    2856                 _COMMAND_LOGGER,
#    2857                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2860                 operationId=self._operation_id,
#    2861             )
# -> 2862         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2863 except PyMongoError as exc:
#    2864     if not self._retryable:
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:593, in _Bulk.execute_command.<locals>.retryable_bulk(session, conn, retryable)
#     590 def retryable_bulk(
#     591     session: Optional[ClientSession], conn: Connection, retryable: bool
#     592 ) -> None:
# --> 593     self._execute_command(
#     594         generator,
#     595         write_concern,
#     596         session,
#     597         conn,
#     598         op_id,
#     599         retryable,
#     600         full_result,
#     601     )
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:538, in _Bulk._execute_command(self, generator, write_concern, session, conn, op_id, retryable, full_result, final_write_concern)
#     536 # Run as many ops as possible in one command.
#     537 if write_concern.acknowledged:
# --> 538     result, to_send = self._execute_batch(bwc, cmd, ops, client)
#     540     # Retryable writeConcernErrors halt the execution of this run.
#     541     wce = result.get("writeConcernError", {})
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:462, in _Bulk._execute_batch(self, bwc, cmd, ops, client)
#     460 else:
#     461     request_id, msg, to_send = bwc.batch_command(cmd, ops)
# --> 462     result = self.write_command(bwc, cmd, request_id, msg, to_send, client)  # type: ignore[arg-type]
#     464 return result, to_send
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\bulk.py:274, in _Bulk.write_command(self, bwc, cmd, request_id, msg, docs, client)
#     272     bwc._start(cmd, request_id, docs)
#     273 try:
# --> 274     reply = bwc.conn.write_command(request_id, msg, bwc.codec)  # type: ignore[misc]
#     275     duration = datetime.datetime.now() - bwc.start_time
#     276     if _COMMAND_LOGGER.isEnabledFor(logging.DEBUG):
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\pool.py:502, in Connection.write_command(self, request_id, msg, codec_options)
#     494 """Send "insert" etc. command, returning response as a dict.
#     495
#     496 Can raise ConnectionFailure or OperationFailure.
#    (...)
#     499 :param msg: bytes, the command message.
#     500 """
#     501 self.send_message(msg, 0)
# --> 502 reply = self.receive_message(request_id)
#     503 result = reply.command_response(codec_options)
#     505 # Raises NotPrimaryError or OperationFailure.
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\pool.py:470, in Connection.receive_message(self, request_id)
#     468 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     469 except BaseException as error:
# --> 470     self._raise_connection_failure(error)
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\synchronous\pool.py:467, in Connection.receive_message(self, request_id)
#     462 """Receive a raw BSON message or raise ConnectionFailure.
#     463
#     464 If any exception is raised, the socket is closed.
#     465 """
#     466 try:
# --> 467     return receive_message(self, request_id, self.max_message_size)
#     468 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     469 except BaseException as error:
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\network_layer.py:343, in receive_data(conn, length, deadline)
#     339 try:
#     340     # Use the legacy wait_for_read cancellation approach on PyPy due to PYTHON-5011.
#     341     # also use it on Windows due to PYTHON-5405
#     342     if _PYPY or _WINDOWS:
# --> 343         wait_for_read(conn, deadline)
#     344         if _csot.get_timeout() and deadline is not None:
#     345             conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
#
# File d:\DATA SCIENCE AND ANALYSIS\MLOPS\Vikash Das\10_Mongodb_Setup\YT-MLOPS-Proj1\vehicle\lib\site-packages\pymongo\network_layer.py:318, in wait_for_read(conn, deadline)
#     316     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     317 if conn.cancel_context.cancelled:
# --> 318     raise _OperationCancelled("operation cancelled")
#     319 if readable:
#     320     return
#
# _OperationCancelled: operation cancelled
